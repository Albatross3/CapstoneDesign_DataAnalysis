# %% [markdown]
# # Cardio data에 대한 Autoencoder Based Clustering

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from scipy.io import loadmat 
cardio_data= loadmat("/content/drive/MyDrive/캡스톤/dataset/cardio.mat")

# %%
print(cardio_data['y'].size)
for i in len(cardio_data['y'].size):
# Out:
# 1831
